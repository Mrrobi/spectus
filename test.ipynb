# %%
import os

from dotenv import load_dotenv

load_dotenv()
import nest_asyncio

nest_asyncio.apply()

# %%
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %%
pip install spectus
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 0.1.0 Requires-Python >=3.12; 0.2.2 Requires-Python >=3.12; 0.2.3 Requires-Python >=3.12
# ERROR: Could not find a version that satisfies the requirement spectus (from versions: none)
# ERROR: No matching distribution found for spectus

# %%
from spectus import extract

result = extract(
    url="https://eie.no/in/property/85260095",
    instruction="extract the pdf download link for the sales document",
    openai_api_key=OPENAI_API_KEY,
)

# %%
result
# Out:
# {'status': 'success',
#  'url': 'https://eie.no/in/property/85260095',
#  'instruction': 'extract the pdf download link for the sales document',
#  'records': [{'pdf_download_link': 'https://cdn.eiendomssentralen.no/media/eie/3590700/digital_salgsoppgave-85260095-2026-05-18--02-55-v1.0.1.pdf'}],
#  'diagnostics': {'strategy_used': 'single_dom_selector',
#   'page_type': 'table_page',
#   'static_or_browser': 'static',
#   'records_found': 1,
#   'quality_score': 1.0,
#   'field_coverage': {'pdf_download_link': 1.0},
#   'missing_required': {'pdf_download_link': 0},
#   'repair_attempts': 0,
#   'template_used': False,
#   'template_id': 'b983b969-47e3-4ddd-9af4-257aeba5a192',
#   'runtime_ms': 8312,
#   'llm_calls': 3,
#   'llm_tokens_in': 7988,
#   'llm_tokens_out': 839,
#   'warnings': []},
#  'message': None}
