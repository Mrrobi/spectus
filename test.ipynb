# %%
import os

from dotenv import load_dotenv

load_dotenv()
import nest_asyncio

nest_asyncio.apply()

# %%
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %%
pip install spectus
# Out:
# ...
#   Using cached aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached trafilatura-2.0.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached structlog-25.5.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached extruct-0.18.0-py2.py3-none-any.whl.metadata (36 kB)
# ...
#   Using cached tldextract-5.3.1-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mako-1.3.12-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached lxml_html_clean-0.4.4-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached rdflib-7.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached pyrdfa3-3.6.5-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached mf2py-2.0.1-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached w3lib-2.4.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached html_text-0.7.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached jstyleson-0.0.2.tar.gz (2.0 kB)
# ...

# %%
from spectus import extract

result = extract(
    url="https://eie.no/in/property/85260095",
    instruction="extract the pdf download link for the sales document",
    openai_api_key=OPENAI_API_KEY,
)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-14' coro=<Connection.run() done, defined at d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "d:\conda_envs\main_env\Lib\asyncio\tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_connection.py", line 312, in run
#     await self._transport.connect()
#   File "d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\conda_envs\main_env\Lib\asyncio\subprocess.py", line 223, in create_subprocess_exec
# ...

# %%
result
# Out:
# {'status': 'success',
#  'url': 'https://eie.no/in/property/85260095',
#  'instruction': 'extract the pdf download link for the sales document',
#  'records': [{'pdf_download_link': 'https://cdn.eiendomssentralen.no/media/eie/3590700/digital_salgsoppgave-85260095-2026-05-18--02-55-v1.0.1.pdf'}],
#  'diagnostics': {'strategy_used': 'single_dom_selector',
#   'page_type': 'table_page',
#   'static_or_browser': 'static',
#   'records_found': 1,
#   'quality_score': 1.0,
#   'field_coverage': {'pdf_download_link': 1.0},
#   'missing_required': {'pdf_download_link': 0},
#   'repair_attempts': 0,
#   'template_used': False,
#   'template_id': 'b983b969-47e3-4ddd-9af4-257aeba5a192',
#   'runtime_ms': 8312,
#   'llm_calls': 3,
#   'llm_tokens_in': 7988,
#   'llm_tokens_out': 839,
#   'warnings': []},
#  'message': 'cached_idempotent_response'}

# %%
from spectus import extract

result = extract(
    url="https://www.finn.no/realestate/homes/ad.html?finnkode=463890441",
    instruction="extract the key information section from this ad please",
    openai_api_key=OPENAI_API_KEY,
)
result
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-34' coro=<Connection.run() done, defined at d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "d:\conda_envs\main_env\Lib\asyncio\tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_connection.py", line 312, in run
#     await self._transport.connect()
#   File "d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "d:\conda_envs\main_env\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\conda_envs\main_env\Lib\asyncio\subprocess.py", line 223, in create_subprocess_exec
# ...
